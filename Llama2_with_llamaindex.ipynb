# %% [markdown]
# ## RAG System Using Llama2 With Hugging Face

# %%
# !pip install pypdf
# Out:
# Requirement already satisfied: pypdf in .\finance_env\lib\site-packages (4.1.0)
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install -q transformers einops accelerate langchain bitsandbytes
# Out:
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
## Embedding
# !pip install install sentence_transformers
# Out:
# Requirement already satisfied: install in .\finance_env\lib\site-packages (1.3.5)
# Requirement already satisfied: sentence_transformers in .\finance_env\lib\site-packages (2.6.1)
# Requirement already satisfied: transformers<5.0.0,>=4.32.0 in .\finance_env\lib\site-packages (from sentence_transformers) (4.39.1)
# Requirement already satisfied: tqdm in .\finance_env\lib\site-packages (from sentence_transformers) (4.66.2)
# Requirement already satisfied: torch>=1.11.0 in .\finance_env\lib\site-packages (from sentence_transformers) (2.2.1)
# Requirement already satisfied: numpy in .\finance_env\lib\site-packages (from sentence_transformers) (1.26.4)
# Requirement already satisfied: scikit-learn in .\finance_env\lib\site-packages (from sentence_transformers) (1.4.1.post1)
# Requirement already satisfied: scipy in .\finance_env\lib\site-packages (from sentence_transformers) (1.12.0)
# Requirement already satisfied: huggingface-hub>=0.15.1 in .\finance_env\lib\site-packages (from sentence_transformers) (0.20.3)
# Requirement already satisfied: Pillow in .\finance_env\lib\site-packages (from sentence_transformers) (10.2.0)
# Requirement already satisfied: filelock in .\finance_env\lib\site-packages (from huggingface-hub>=0.15.1->sentence_transformers) (3.13.3)
# Requirement already satisfied: fsspec>=2023.5.0 in .\finance_env\lib\site-packages (from huggingface-hub>=0.15.1->sentence_transformers) (2024.3.1)
# Requirement already satisfied: requests in .\finance_env\lib\site-packages (from huggingface-hub>=0.15.1->sentence_transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in .\finance_env\lib\site-packages (from huggingface-hub>=0.15.1->sentence_transformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in .\finance_env\lib\site-packages (from huggingface-hub>=0.15.1->sentence_transformers) (4.10.0)
# Requirement already satisfied: packaging>=20.9 in .\finance_env\lib\site-packages (from huggingface-hub>=0.15.1->sentence_transformers) (23.2)
# Requirement already satisfied: sympy in .\finance_env\lib\site-packages (from torch>=1.11.0->sentence_transformers) (1.12)
# Requirement already satisfied: networkx in .\finance_env\lib\site-packages (from torch>=1.11.0->sentence_transformers) (3.2.1)
# Requirement already satisfied: jinja2 in .\finance_env\lib\site-packages (from torch>=1.11.0->sentence_transformers) (3.1.3)
# Requirement already satisfied: colorama in .\finance_env\lib\site-packages (from tqdm->sentence_transformers) (0.4.6)
# Requirement already satisfied: regex!=2019.12.17 in .\finance_env\lib\site-packages (from transformers<5.0.0,>=4.32.0->sentence_transformers) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in .\finance_env\lib\site-packages (from transformers<5.0.0,>=4.32.0->sentence_transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in .\finance_env\lib\site-packages (from transformers<5.0.0,>=4.32.0->sentence_transformers) (0.4.2)
# Requirement already satisfied: joblib>=1.2.0 in .\finance_env\lib\site-packages (from scikit-learn->sentence_transformers) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in .\finance_env\lib\site-packages (from scikit-learn->sentence_transformers) (3.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in .\finance_env\lib\site-packages (from jinja2->torch>=1.11.0->sentence_transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in .\finance_env\lib\site-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in .\finance_env\lib\site-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in .\finance_env\lib\site-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in .\finance_env\lib\site-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in .\finance_env\lib\site-packages (from sympy->torch>=1.11.0->sentence_transformers) (1.3.0)
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install llama_index

# %%
# !pip install llama-index-llms-huggingface
# Out:
# Requirement already satisfied: llama-index-llms-huggingface in .\finance_env\lib\site-packages (0.1.4)
# Requirement already satisfied: huggingface-hub<0.21.0,>=0.20.3 in .\finance_env\lib\site-packages (from llama-index-llms-huggingface) (0.20.3)
# Requirement already satisfied: llama-index-core<0.11.0,>=0.10.1 in .\finance_env\lib\site-packages (from llama-index-llms-huggingface) (0.10.24.post1)
# Requirement already satisfied: torch<3.0.0,>=2.1.2 in .\finance_env\lib\site-packages (from llama-index-llms-huggingface) (2.2.1)
# Requirement already satisfied: transformers<5.0.0,>=4.37.0 in .\finance_env\lib\site-packages (from transformers[torch]<5.0.0,>=4.37.0->llama-index-llms-huggingface) (4.39.1)
# Requirement already satisfied: filelock in .\finance_env\lib\site-packages (from huggingface-hub<0.21.0,>=0.20.3->llama-index-llms-huggingface) (3.13.3)
# Requirement already satisfied: fsspec>=2023.5.0 in .\finance_env\lib\site-packages (from huggingface-hub<0.21.0,>=0.20.3->llama-index-llms-huggingface) (2024.3.1)
# Requirement already satisfied: requests in .\finance_env\lib\site-packages (from huggingface-hub<0.21.0,>=0.20.3->llama-index-llms-huggingface) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in .\finance_env\lib\site-packages (from huggingface-hub<0.21.0,>=0.20.3->llama-index-llms-huggingface) (4.66.2)
# Requirement already satisfied: pyyaml>=5.1 in .\finance_env\lib\site-packages (from huggingface-hub<0.21.0,>=0.20.3->llama-index-llms-huggingface) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in .\finance_env\lib\site-packages (from huggingface-hub<0.21.0,>=0.20.3->llama-index-llms-huggingface) (4.10.0)
# Requirement already satisfied: packaging>=20.9 in .\finance_env\lib\site-packages (from huggingface-hub<0.21.0,>=0.20.3->llama-index-llms-huggingface) (23.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in .\finance_env\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (2.0.29)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in .\finance_env\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (3.9.3)
# Requirement already satisfied: dataclasses-json in .\finance_env\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (0.6.4)
# Requirement already satisfied: deprecated>=1.2.9.3 in .\finance_env\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in .\finance_env\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (1.0.8)
# Requirement already satisfied: httpx in .\finance_env\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (0.27.0)
# Requirement already satisfied: llamaindex-py-client<0.2.0,>=0.1.13 in .\finance_env\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (0.1.13)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in .\finance_env\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in .\finance_env\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (3.2.1)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in .\finance_env\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (3.8.1)
# Requirement already satisfied: numpy in .\finance_env\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (1.26.4)
# Requirement already satisfied: openai>=1.1.0 in .\finance_env\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (1.14.3)
# Requirement already satisfied: pandas in .\finance_env\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (2.2.1)
# Requirement already satisfied: pillow>=9.0.0 in .\finance_env\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (10.2.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in .\finance_env\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (8.2.3)
# Requirement already satisfied: tiktoken>=0.3.3 in .\finance_env\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (0.6.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in .\finance_env\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (0.9.0)
# Requirement already satisfied: sympy in .\finance_env\lib\site-packages (from torch<3.0.0,>=2.1.2->llama-index-llms-huggingface) (1.12)
# Requirement already satisfied: jinja2 in .\finance_env\lib\site-packages (from torch<3.0.0,>=2.1.2->llama-index-llms-huggingface) (3.1.3)
# Requirement already satisfied: regex!=2019.12.17 in .\finance_env\lib\site-packages (from transformers<5.0.0,>=4.37.0->transformers[torch]<5.0.0,>=4.37.0->llama-index-llms-huggingface) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in .\finance_env\lib\site-packages (from transformers<5.0.0,>=4.37.0->transformers[torch]<5.0.0,>=4.37.0->llama-index-llms-huggingface) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in .\finance_env\lib\site-packages (from transformers<5.0.0,>=4.37.0->transformers[torch]<5.0.0,>=4.37.0->llama-index-llms-huggingface) (0.4.2)
# Requirement already satisfied: accelerate>=0.21.0 in .\finance_env\lib\site-packages (from transformers[torch]<5.0.0,>=4.37.0->llama-index-llms-huggingface) (0.28.0)
# Requirement already satisfied: psutil in .\finance_env\lib\site-packages (from accelerate>=0.21.0->transformers[torch]<5.0.0,>=4.37.0->llama-index-llms-huggingface) (5.9.8)
# Requirement already satisfied: aiosignal>=1.1.2 in .\finance_env\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in .\finance_env\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in .\finance_env\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in .\finance_env\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in .\finance_env\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in .\finance_env\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (4.0.3)
# Requirement already satisfied: wrapt<2,>=1.10 in .\finance_env\lib\site-packages (from deprecated>=1.2.9.3->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (1.16.0)
# Requirement already satisfied: pydantic>=1.10 in .\finance_env\lib\site-packages (from llamaindex-py-client<0.2.0,>=0.1.13->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (2.6.4)
# Requirement already satisfied: anyio in .\finance_env\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (4.3.0)
# Requirement already satisfied: certifi in .\finance_env\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in .\finance_env\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (1.0.4)
# Requirement already satisfied: idna in .\finance_env\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (3.6)
# Requirement already satisfied: sniffio in .\finance_env\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in .\finance_env\lib\site-packages (from httpcore==1.*->httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (0.14.0)
# Requirement already satisfied: click in .\finance_env\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (8.1.7)
# Requirement already satisfied: joblib in .\finance_env\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (1.3.2)
# Requirement already satisfied: distro<2,>=1.7.0 in .\finance_env\lib\site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (1.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in .\finance_env\lib\site-packages (from requests->huggingface-hub<0.21.0,>=0.20.3->llama-index-llms-huggingface) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in .\finance_env\lib\site-packages (from requests->huggingface-hub<0.21.0,>=0.20.3->llama-index-llms-huggingface) (2.2.1)
# Requirement already satisfied: greenlet!=0.4.17 in .\finance_env\lib\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (3.0.3)
# Requirement already satisfied: colorama in .\finance_env\lib\site-packages (from tqdm>=4.42.1->huggingface-hub<0.21.0,>=0.20.3->llama-index-llms-huggingface) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in .\finance_env\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in .\finance_env\lib\site-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (3.21.1)
# Requirement already satisfied: MarkupSafe>=2.0 in .\finance_env\lib\site-packages (from jinja2->torch<3.0.0,>=2.1.2->llama-index-llms-huggingface) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\finance_env\lib\site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in .\finance_env\lib\site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in .\finance_env\lib\site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (2024.1)
# Requirement already satisfied: mpmath>=0.19 in .\finance_env\lib\site-packages (from sympy->torch<3.0.0,>=2.1.2->llama-index-llms-huggingface) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in .\finance_env\lib\site-packages (from anyio->httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in .\finance_env\lib\site-packages (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.13->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in .\finance_env\lib\site-packages (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.13->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (2.16.3)
# Requirement already satisfied: six>=1.5 in .\finance_env\lib\site-packages (from python-dateutil>=2.8.2->pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (1.16.0)
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from llama_index.core import VectorStoreIndex,SimpleDirectoryReader,ServiceContext
from llama_index.llms.huggingface import HuggingFaceLLM
from llama_index.core.prompts.prompts import SimpleInputPrompt

# %%
documents=SimpleDirectoryReader("data").load_data()
documents
# Out:
# [Document(id_='20569f43-d10c-47b2-aa5b-7d2a5971088f', embedding=None, metadata={'page_label': '1', 'file_name': 'maruti.pdf', 'file_path': 'f:\\finance-ai-project\\data\\maruti.pdf', 'file_type': 'application/pdf', 'file_size': 152706, 'creation_date': '2024-03-27', 'last_modified_date': '2024-03-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text=' \n1 | P a g e  \n MSIL Conference Call Transcript 31 January  2024 \n  \n \nQ3 FY24 – Investor Conference Call  \n \n \nJanuary  31, 202 4 \n \n \n \n \n \n \n \n  \n \n \n \n  \n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='4e7008f9-68b8-44f2-acaa-bbf7df38cb83', embedding=None, metadata={'page_label': '2', 'file_name': 'maruti.pdf', 'file_path': 'f:\\finance-ai-project\\data\\maruti.pdf', 'file_type': 'application/pdf', 'file_size': 152706, 'creation_date': '2024-03-27', 'last_modified_date': '2024-03-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='  \n2 | P a g e  \n MSIL Conference Call Transcript 31 January 2024  \n Moderator:  Ladies and gentlemen, good day and welcome to the Q3 FY24 Earnings Conference Call of Maruti Suzuki India \nLimited.  \nAs a reminder, all participant lines will be in the listen only mode, and there will be an opportunity for you to \nask questions after the presentation concludes. Should you need assistance during the conference call, please \nsignal the operator by pressing “*” and then “0” on your touchtone ph one. Please note that this conference is \nbeing recorded.  \nI now hand the conference over to Mr. Pranav Ambaprasad. Thank you and over to you sir.  \nPranav Ambaprasad:  Thank you, Sagar. Ladies and gentlemen, good afternoon once again. Welcome you all to the Q3  FY24 Earnings \nCall. May I introduce you to the Management Team of Maruti Suzuki.  \nToday we have with us our Chief Investor Relations Officer, Mr. Rahul Bharti, and CFO, Mr. Arnab Roy.  \nBefore we begin, may I remind you of the safe harbor. We may be making some forward -looking statements that \nhave to be understood in conjunction with the uncertainty and the risks that the Company faces. I would also like \nto inform you that the call is being recorded, and the audio recording and the transcript will be availab le on our \nwebsite. Please note that in case of any inadvertent error during this live audio call, the transcript will be provided \nwith the corrected information.  \nThe con ference call will begin with a brief statement on the performance and outlook of the bu siness by the Chief \nInvestor Relations Officer and Executive Officer, Corporate Planning, Mr. Rahul Bharti, after which we will be \nhappy to receive your questions.  \nI would now like to invite our Chief Investor Relations Officer, Mr. Rahul Bharti. Over to y ou, sir.  \nRahul Bharti:  Thanks Pranav. Good afternoon, ladies and gentlemen and thank you for joining us. Today I will share an \noverview of the industry and sales performance followed by the business performance of the Company.  \nThe Indian passenger vehicle industry registered a record sale of 4.1 million units in the calendar year 2023, \nmaking it the third largest market in the world. In the industry the share of the utility vehicle segment continues \nto expand. In Quarter 3, the share of SUVs increased to ab out 53%. Together with MUV, the share of UV in the \nindustry is about 63%.  \nIn terms of fuel type, the share of CNG vehicles in the industry further expanded to about 16.5% in Quarter 3. \nHybrid vehicles have also seen good traction and now the share of hybr id vehicles has increased to ~2%.  \nI would also like to share some of the sustainability initiatives of the Company.   \n• As you may be aware, for an automobile company the carbon emissions from its products contribute to \nabout 80% of the total emissions.  As per the last released fuel efficiency compliance report from the Ministry \nof Road Transport, the Company had the lowest carbon emitting fleet in Financial Year 21 -22. The second \nphase of CAFE Regulations was implemented in the last financial year, when the CO2 emission targets \nwere tightened. The results are yet to be released, but Maruti Suzuki is confident of meeting its target and \nvery hopeful of maintaining the leadership in terms of lowest carbon emitting fleet.  ', start_char_idx=None, end_char_idx=None, text_templa ...
#  Document(id_='7c00d40c-8658-4a38-a21d-818abebac902', embedding=None, metadata={'page_label': '3', 'file_name': 'maruti.pdf', 'file_path': 'f:\\finance-ai-project\\data\\maruti.pdf', 'file_type': 'application/pdf', 'file_size': 152706, 'creation_date': '2024-03-27', 'last_modified_date': '2024-03-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='  \n3 | P a g e  \n MSIL Conference Call Transcript 31 January 2024  \n • The Company has embraced a multiple powertrain approach rather than focusing on a single technology to \nreduce the carbon footprint of its entire fleet.  \n• In CNG, a strong portfolio of 14 vehicles is helping the Company in lowering carbon emissions. Also, CNG \nfueled vehicles have lower running costs. In Quarter 3, with sales of over 127,000 units, the contribution of \nCNG vehicles in our sales has increased to an all -time high of ~30%. In future, the Company is exploring \nthe option of compressed biogas.  \n• The Company is on course to start productio n of battery electric vehicles in 2024. In addition to serving the \ndomestic market, this mid - SUV segment product will be exported to developed markets such as Japan and \nEurope.  \n• Apart from products, the Company also focuses on reducing the carbon emission  in its operations. Use of \nrailway in dispatches of vehicles is one such initiative. In 2023, a record 422,000 vehicles were dispatched \nthrough railways. The share of railways in total vehicle dispatches has increased to over 20%. The upcoming \nrailway sidi ng at Manesar plant will further help in increasing the vehicle dispatches through railways.   \n• With the objective of increasing the use of renewable power, in the next financial year, the Company is \nplanning to increase its solar power generation capacity f rom 26.3 MWp to over 48 MWp.  \nLet me now share some of the business highlights of the Company:  \n• In calendar year 2023, Maruti Suzuki crossed the annual sales milestone of 2 million units, which is its \nhighest ever sales in a calendar year.  \n• With its highest  ever exports of about 270,000 units in 2023, the Company continues to be the largest \nexporter of passenger vehicles from India .  \n• With a good market acceptance of all its seven utility vehicles ranging from entry SUV, Fronx to top of the \nline Invicto, the Company continues to be a market leader in the utility vehicle segment.  \n• During this financial year, the Grand Vitara became the fastest mid -SUV to clock the 1 lakh sales milestone.  \n• Now, Fronx SUV has set a new benchmark in the passenger vehicle category b y becoming the only new \nmodel launch to clock one lakh sales in 10 months.  \n• The Company is optimistic on the growth prospects of domestic market as well as the export potential of \ncars from India. The Company is planning a two - fold increase in its annual production capacity to about 4 \nmillion by 2030 -31. \n• The setting up of a greenfield project in Kharkhoda, Haryana, is part of its ambitious plan. Construction is \nalready in progress at Kharkhoda and the first plant with an annual production capacity of 250,0 00 units is \non course to be operational in 2025. The Company has space to set up four such plants with a total capacity \nof 1 million units in Kharkhoda.  \n• Recently, in Vibrant Gujarat Summit 2024, the Company signed a MoU with the Government of Gujarat as \na preference to set up a new automobile manufacturing facility. This is subject to the availability of suitable \nland. This new plant in Gujarat is aimed to start operation in FY 28 -29. In the future, the annual production \ncapacity is expected to become 1 mil lion units with a total investment amount of Rs. 35,000 crores. After \nfinalization of land and due approval from  ...
#  Document(id_='baf29847-3907-4f13-b4b3-cc56adef7dd4', embedding=None, metadata={'page_label': '4', 'file_name': 'maruti.pdf', 'file_path': 'f:\\finance-ai-project\\data\\maruti.pdf', 'file_type': 'application/pdf', 'file_size': 152706, 'creation_date': '2024-03-27', 'last_modified_date': '2024-03-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='  \n4 | P a g e  \n MSIL Conference Call Transcript 31 January 2024  \n material cost in standalone results also includes employee cost, manufacturing overheads and operating \nincome of SMG. So, these 3 items have been removed from raw material cost and adjusted into their natural \nheads in the consolidated results . Similarly, the depreciation of SMG, which is accounted in manufacturing \ncost in standalone results, has been shifted to depreciation cost head in consolidated results . Effectively, in \nthe consolidated statement, the EBITDA marg in has adjusted upwards while the EBIT margin is largely at \na similar level.  \nComing to the highlights of Q3 (October -December), FY 2023 -24 \nThe Company sold a total of 501,207 vehicles during the quarter. Sales in the domestic market were 429,422 \nunits. The Company exported 71,785 cars, the highest ever in any quarter. The same period in the previous year \nsaw total sales of 465,911 units compr ising 403,929 units in domestic and 61,982 units in the export market.  \nThe growth in net sales outpaced the growth in sales volume due to a higher contribution of utility vehicles to \ntotal sales volume. And with this, the ASP increased by 6%.  \nThe net profit for the quarter rose to INR 31,300 million from INR 23,513 million in Q3 FY22 -23, a year -on-\nyear growth of over 33%. This was on account of higher sales volume, cost reduction efforts,  favorable \ncommodity prices and higher non -operating income.   \nCom ing to the highlights of nine months (April to December), FY 2023 -24 \nIn 9M FY23 -24, the Company recorded its highest ever nine monthly sales volume, net sales, operating profit, \nand net profit. The Company sold a total of 1,552,292 vehicles, registering a growth of 6.9% over 9M FY22 -23. \nOut of the total sales volume, 1,346,965 units were sold in the domestic market and 204,327 units were exported.  \nThe Company registered net sales of INR 982,403 million, a growth of 22.3% over the period of April -\nDecember’2 2.  \nYou may like to take note of the fact that our revenue from operations has crossed INR 1 lakh crores in the nine -\nmonth period, which we did in the last full financial year. Even on full year basis, only few manufacturing \ncompanies in India could achiev e this feat.  \nWe are now ready to take your questions, feedback, and any other observations that you may have. Thank \nyou. \nModerator:   Thank you. We will now begin the question -and-answer session. The first question is from the line of Pramod \nKumar from UBS . Please go ahead.  \nPramod Kumar:  Rahul Sir, are there any one -offs in the quarterly results? Given the high retail velocity, what was the per car \ndiscount number? I will then follow up on the margins.  \nRahul Bharti:   No real one -offs as such. The discount in the quarter on wholesale s was around INR 23,300  per vehicle . This is \nagainst the discount of INR 17,700 per vehicle in Q2 FY23 -24. We must keep in mind that this discount is \ndistributed over wholesales, while we give discounts on retail sales.  ', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='5141b5b9-a668-4e69-b2d1-0f2ddbb8b2b6', embedding=None, metadata={'page_label': '5', 'file_name': 'maruti.pdf', 'file_path': 'f:\\finance-ai-project\\data\\maruti.pdf', 'file_type': 'application/pdf', 'file_size': 152706, 'creation_date': '2024-03-27', 'last_modified_date': '2024-03-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='  \n5 | P a g e  \n MSIL Conference Call Transcript 31 January 2024  \n Pramod Kum ar:  The margin numbers look interesting because you were close to 11% last quarter, with the best of the utilization \nand wholesales and despite offering higher discount. Should I presume, some of this should roll off?  How should \none look at the margin out look?  Is it probable that Maruti’s margin band has now moved to a double -digit range?  \nRahul Bharti:  We never comment on margin outlook. But we can certainly discuss the margin drivers individually. You are \naware of the margin drivers. The biggest factor that affects us is the volume. And you would know that in the \nauto sector, the 4th Quarter is usually a good quarter, because of cyclicity and seasonality.  \nThe second element is stock at dealership. At the end of the calendar year, we try to minimize stock at dealerships. \nHence, in quarter 3, retail sales usually exceed wholesale. In quarter 4, you need a  healthy stock in the market to \nrecover the stock levels. To that extent, discounting should be optimal. which is a positive for us. We have \nannounced a price increase in the range of about 0.45% , which will also help.  \nIn commodities, steel might show some  upward movement. We expect some continuation of the past benefits on \nmovement in PGM, palladium, rhodium, etc. On FOREX, we had gains in Quarter 3  on direct imports and \nindirect imports happen with a lag. Hence, the benefit should continue in Quarter 4. F or direct imports, the rates \nwhich are prevalent in Quarter 4 will apply. However, we are dependent on the volume uncertainty of the market, \nwhich continues.  \nPramod Kumar:   Fair enough. The second question is on the retail sales scenario and the inventory  situation. We have FADA  \nmentioning alarmingly high levels of inventory in the car industry, predominantly in the small car segment. \nWhere does your inventory stand, at the end of the quarter? What would be the likely month end inventory with \nyour dealers?  How has the small car inventory moved over the last few quarters? Can you help us understand the \noverall inventory situation, especially for the small cars? Since this will have an impact on discount levels going \nforward.  \nRahul Bharti:   I won’t be making forward looking statements.  There’s a lot to do with the fine print and the assumptions.  Maruti \nSuzuki had a low and healthy closing stock. The quarter ended with the stock below 45,000 units. We started the \nNew Year light and ready to provide more cars to  the dealerships. On the inventories in the market , there is no \nconcern  and it’s a normal and healthy situation. We have pending bookings of about 215,000 vehicles at the end \nof Quarter 3.   \nModerator:   Thank you. The next question is from the line of Gunja n Prithyani from Bank of America. Please go ahead.  \nGunjan Prithyani:  Couple of questions from my side. First, expanding on the data that you gave on discounts, can you talk about \nthe retail sales in Quarter 3 FY23 -24? \nRahul Bharti:  Retail sales in Quarter 3 were much higher than the wholesales. We retailed ~530,000 vehicles, which was a \nreduction of ~115,000 units from network stock.  \nGunjan Prithyani:  Okay, got it. Any meaningful change in the royalty numbers? or does it stay in that same range, around 3.7% to \n3.8%?  \nRahul Bharti:  The royalty stands at 3.5% which  ...
#  Document(id_='74958aed-94c6-4635-94be-862362588b68', embedding=None, metadata={'page_label': '6', 'file_name': 'maruti.pdf', 'file_path': 'f:\\finance-ai-project\\data\\maruti.pdf', 'file_type': 'application/pdf', 'file_size': 152706, 'creation_date': '2024-03-27', 'last_modified_date': '2024-03-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='  \n6 | P a g e  \n MSIL Conference Call Transcript 31 January 2024  \n Gunjan Prithyani:  Okay, got it. Now, my question next question is on growth. Going into FY 2025, how should we think about \ngrowth? What is the outlook on customer bookings and inquiries? How is the mini and compact car portfolio of \nMaruti Suzuki c ontinuing to shrink? What is your outlook on industry growth and Maruti Suzuki’s growth, given \nthe high exposure of the Company to the mass segment.  \nRahul Bharti:  Before addressing the growth outlook in next financial year , I should mention that India n passenger vehicle \nmarket  is already at a high base. This year, the industry will sell  ~4.2 million vehicles. Although not finalized at \nthe CEO level, SIAM has made preliminary sales estimates for next year. According to the preliminary discussion \nin ‘16th SIAM Looking Ahead Conclave’, in the next year, 4.3 million vehicle sales are expected. Maruti Suzuki \nintends to grow faster than the industry. You are right, the industry growth could be much better had it not been \nfor the small car segment.  The small car  segment is shrinking, in both percentage terms and in absolute terms.  \nDue to regulatory intensity and introduction of too many regulations together, the cost went up suddenly. There \nis a strong latent customer demand for cars, but it’s a function of affo rdability. In simple economic terms, \naffordability is the only big hurdle. We think, as the income growth catches up with the increased acquisition \ncost, small car demand should revive. Hence, we are putting our hopes on the small car segment to come back \nin future, but not immediately.  \nGunjan Prithyani:  Okay, got it. The second question I have is on the product side. You have done a lot in terms of plugging the \nSUV gap in your product portfolio. But are there more white spaces in your product portfolio tha t you are \nplanning to address in the coming 12 -18 months? Maruti Suzuki is not present in the micro - UV segment. Should \nwe expect new product launches in the next 1 to 3 years?  \nRahul Bharti:  As we have announced, we will have 28 models by the turn of this  decade. This means we must develop at least \n10 more models. This is in addition to models that need to be refreshed. So, certainly there is a strong model \npipeline and of course, the model pipeline must reflect the consumer preferences. We will be where c onsumers \nwant us to be. One model that I can talk about is our EV, which will enter production i n this calendar year.  This \nmodel will also be exported. But we will be covering all segments that are important from a volume point of \nview.  \nModerator:   Thank you. The next question is from the line of Raghunandhan N L from Nuvama Research. Please go ahead.  \nRaghunandhan N L:  Couple of questions Sir. First, the first -time buyer’s share has reduced to ~40% from pre COVID levels of ~50%. \nWhat is your outlook on triggers for first time buyer demand recovery? And do you see any trends which can \ntrigger this recovery?  \nRahul Bharti:  A very interesting question Raghunandan. We are analyzing this very carefully. The highest  (first time buyer \nshare)  we had reached re cently was 47% in FY 2021.  It went to a low of 38% in Quarter 2 FY 23 -24. In Quarter \n3 FY 23 -24, it inched upwards to 41%. However, it is too premature to conclude whether it’s a green shoot  ...
#  Document(id_='80f01c32-20c1-4ffb-9ccd-57a0df35739e', embedding=None, metadata={'page_label': '7', 'file_name': 'maruti.pdf', 'file_path': 'f:\\finance-ai-project\\data\\maruti.pdf', 'file_type': 'application/pdf', 'file_size': 152706, 'creation_date': '2024-03-27', 'last_modified_date': '2024-03-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='  \n7 | P a g e  \n MSIL Conference Call Transcript 31 January 2024  \n bottleneck.  And as you notice, in Q2 FY 23 -24, we did sales comparable to our production capacity. We need \nsome headroom in production capacity if we want to attain growth. By March’24, in Manesar, we will have \n~100,000 units capacity  addition . And we c ould also utilize Gujarat more. In the year 2025, we should have the \nfirst production  line of 250,000 units operating at Kharkhoda plant. When there’s a ramp up, you don’t get full \ncapacity on day one. But that capacity will come. In the short run, there a re some minor bottlenecks that are \nholding up CNG supplies. These issues will get resolved soon.  \nRaghunandhan N L:  Thank you sir. One last question on the upcoming BEV to be launched in 2024. Historically, Maruti has always \nbeen providing its customers wit h the best cost of ownership. Will this be continued in EVs by configuring a \ndedicated platform and aggressive localization efforts?  \nRahul Bharti:  See the interesting phenomena about EVs in India, the EV customer profile is quite different than that of ICE . \nThe same parameters are not at the top of an EV customer’s mind. Generally, this is a higher segment customer \nwith a charging infrastructure at home. This customer will most likely use the EV to commute to the office and \nhas a predictable usage profile. The first SUV that we are launching in EV space is an upmarket vehicle. It’s \nbigger than the Grand Vitara, it has a high range, almost 550 -kilometer, battery capacity of 60 kilowatt hours. \nWe have taken care of customers’ range anxiety extremely well. It w ill be a high spec vehicle. We are hopeful \nthat the customers will receive it well.  \nModerator:   Thank you. The next question is from the line of  Vipul Agrawal from HSBC. Please go ahead.  \nVipul Agrawal:  My question is on CNG penetration. How is it shaping up in the southern part of the country?  There is a strong \npenetration of CNG pumps in India now. What is the resultant increase in the CNG vehicles? Can you give me \nboth the overall industry situation and Maruti Suzuki’s situation?  \nRahul Bharti:  Developmen t in CGD infrastructure helps increase the CNG penetration. Some new geographies are being added. \nThis is helping CNG sales. We have reached a CNG penetration of 30.8% and we see headroom going further. \nIn some models, the CNG penetration is more than 50%, Ertiga : 57%, WagonR : 50% and Dzire : 44%. Similarly, \nthere are cities with high CNG penetration. Delhi has 47% CNG penetration. Traditionally, Gujarat, Delhi and \nMumbai used to be strong CNG markets. But now, Pune has picked up  big time. In new cities, where they have \nreached a critical mass of stations, we find good absorption of CNG. We are in contact with the CGD companies \nto have joint promotion schemes. Because of these schemes, we can sell more CNG cars. But the CGD compan ies \nget to sell CNG fuel across vehicle lifecycle. Hence, CGD companies are quite interested in partnering for joint \npromotion of CNG vehicles.  \nVipul Agrawal:  My second question is on the CNG portfolio of Maruti Suzuki. Your models mostly have a single cy linder CNG, \nwhile the competition has launched a 2 -cylinder CNG variant. This product provides much better boot space. \nWhat is Maruti Suzuki’s strategy to counter this? Can we expect a similar product from M ...
#  Document(id_='517c8757-ba90-4a37-982a-9ed9a8095ae4', embedding=None, metadata={'page_label': '8', 'file_name': 'maruti.pdf', 'file_path': 'f:\\finance-ai-project\\data\\maruti.pdf', 'file_type': 'application/pdf', 'file_size': 152706, 'creation_date': '2024-03-27', 'last_modified_date': '2024-03-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='  \n8 | P a g e  \n MSIL Conference Call Transcript 31 January 2024  \n Rahul Bharti:  I’ll take your last question first. We are seeing some logistical challenges because of the Red Sea issue. And \nthere may be some increase in costs because of risk or because of rerouting of vessels but it should not be \nsignificant. The lead time of dispatches might change and there may be some uncertainty in vessels coming and \npicking up t heir consignments , etc. That’s a small issue which is quite common in the export business. In the last \ncalendar year, we exported ~270,000 vehicles. This was the highest ever export number for us. We should be \nable to do better in the coming years. By the turn of this decade, our ambition is to go up to at least 750,000 units \nin annual exports. Africa is turning out to be a good market . For several reasons, the Middle East region has \npicked up quite well, recently. The government is also signing some FTAs w here we get some relief in duty. \nWith UAE we have an FTA in place. FTA is under consideration with six Gulf countries. Latin America is next. \nWith our EV, we will re -enter Europe and Japan.   \nVipul Agrawal:  Yes, Sir. Are you expecting any new model launches  for exports?  \nRahul Bharti:  No. Usually, we sell from our existing portfolio. Jimny -3 Door  was the only unique model that we were \nexporting, but not selling domestically. Now we have Jimny -5 Door . The top models in our exports are Baleno, \nDzire, Jimny, Sw ift and Grand Vitara.  \nModerator:   Thank you. The next question is from the line of  Amyn Pirani from J.P. Morgan. Please go ahead.  \nAmyn Pirani:  Two questions from my side. First is a bookkeeping question on margin improvement. On a Y -o-Y basis, the \nmargins have improved, but on a quarter -on-quarter basis, they have declined. Can you highlight 2 to 3 major \nreasons for the margin movement?  \nRahul Bharti:  I’ll talk about sequential first. I had mentioned in the past, the operating leverage is the largest lever i n \ndetermining the margin. We lost ~110 basis points on account of operating leverage, since in Quarter 3  we have \nlower wholesale and more retail. Discounts adversely impacted the margin by ~70 basis points, advertisement \nwas up by ~30 basis points. So, there was a net negative ~210 basis points. On the positive, we gained on FOREX \nby ~30 basis points, on royalty by ~30 basis points. In commodities, the steel was marginally up, but we gained \nsomewhat on PGM, with a favorable impact of ~10 basis points. So, gain of ~70 basis points. Overall, \nsequentially on EBIT, we had ~130 basis points fall from 11.2% in Quarter 2 to 9.9% in Quarter 3.  \nAmyn Pirani:  Are you seeing a lot of first -time buyers moving upward from smaller cars like WagonR, Celerio and maybe \ngoing straight into micro -SUVs or moving within your portfolio, towards Swift or Baleno?  \nThere is a lot of model launch momentum in micro -SUVs segment, and even more launches are happening on \nthe slightly bigger cars at the entry level. While you still have more than 10 -year-old models. Can you comment \non this?  \nRahul Bharti:  These factors affect the small car demand,  but not in large part. De -growth in small car demand cannot be \nexplained by just this phenomenon. Otherwise, the total growth of the industry would have been much higher. I \ncould  imagine, while there are some custom ...
#  Document(id_='9202cf49-0c05-4762-a746-b588e669f7a2', embedding=None, metadata={'page_label': '9', 'file_name': 'maruti.pdf', 'file_path': 'f:\\finance-ai-project\\data\\maruti.pdf', 'file_type': 'application/pdf', 'file_size': 152706, 'creation_date': '2024-03-27', 'last_modified_date': '2024-03-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='  \n9 | P a g e  \n MSIL Conference Call Transcript 31 January 2024  \n segment in the industry  during  the last quarter has come down to ~25%. At the peak, in FY 17 -18, this number \nwas at ~47%. So, it’s a large shrinkage.  \nAmyn Pirani:  Thank Rahul Sir. If I can just squeeze in a follow up question, if the affordability and the income levels of the \nfirst-time buyer improve in 6, 12 or 15 months, do you think the customers will come back to the lower end hatch \nlevel? or do you think they w ill come at the level of upper end hatch and micro -SUV segment? And if they do \ncome at the lower hatch level, will you also need to make some exciting product launches in that segment?  \nRahul Bharti:  So, it depends on the shape of the consumer pyramid. When ever such a phenomenon happens, it starts from the \nupper end and then goes down deeper. That’s a natural and continuous progression we have seen. We have some \nexciting products  in that segment . You need a very critical balance of all the parameters that a customer looks \nfor and that is continuously being researched. Infotainment  features  and SUV like design are some of the larger \ntrends affecting India.  \nModerator:   Thank you. Ladies and gentlemen, that was the last question for today. With this, we conclude  today’s conference \ncall. On behalf of Maruti Suzuki India Limited, we thank you for joining us and you may now disconnect your \nlines.  \n ', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='de33536c-836d-4a8b-9d4d-ec51355a0d80', embedding=None, metadata={'page_label': '1', 'file_name': 'tata.pdf', 'file_path': 'f:\\finance-ai-project\\data\\tata.pdf', 'file_type': 'application/pdf', 'file_size': 807380, 'creation_date': '2024-03-27', 'last_modified_date': '2024-03-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text=' \n \n  \nFebruary 8 , 2024 \nSc - 18133 \nDear S ir/Madam , \nSub: Transcript o f Q3 FY 2024 Earnings D iscussion/Conference call \nPursuant to Regulation 30 of the SEBI (Listing Obligations and Disclosure Requirements)  \nRegulations, 2015  and with further reference to our lett er sc no. 18089 dated January 17, 2024 , \nenclosing herewith the transcript of the earnings/conference call for the quarter ended \nDecember 31, 2023 conducted after the meeting of Board of Directors held on Friday , \nFebruary 2 , 2024. \nThe t ranscript of th e earnings/conference  call is av ailable on the website of t he C ompany a t \nwww.tatamotors.com  \nThis i s for y our information and records. \nYours f aithfully,  \nTata Motors Li mited \nM\naloy Kumar Gupta \nCompany Secretar y \nE\nncl: a/a  BSE Limited    \nFirst Floor, New Trading Ring  \nRotunda Building, P J Towers,  \nDalal Street, Fort, Mumbai 400 001 National Stock Exchange of India Ltd.  \nListing Compliance Department  \nExchange Plaza, Bandra Kurla Complex, \nBandra(E), Mumbai 400 051 ', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='26eb41d0-673a-4c11-9edd-4d76e942ee18', embedding=None, metadata={'page_label': '2', 'file_name': 'tata.pdf', 'file_path': 'f:\\finance-ai-project\\data\\tata.pdf', 'file_type': 'application/pdf', 'file_size': 807380, 'creation_date': '2024-03-27', 'last_modified_date': '2024-03-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='                                                                                                        Tata Motors Limited  \nFebruary 2, 2024  \n \n \n \n \nTata Motors Group  \nQ3 FY24 earnings call transcript   \n \nMANAGEMENT : MR. PB BALAJI  – GROUP  CFO, TATA  MOTORS  LIMITED  \nMR. ADRIAN  MARDELL  – CEO, JAGUAR  LAND  ROVER  \nMR. GIRISH  WAGH  – EXECUTIVE  DIRECTOR,  TATA  MOTORS  \nLIMITED  \nMR. SHAILESH  CHANDRA  – MD  TMPVL  AND  TPEML   \nMR.  RICHARD  MOLYNEUX  –CFO,  JAGUAR  LAND  ROVER  \nMS. NAMRATA  DIVEKAR  – HEAD , TREASURY , IR, M&A,  TATA  \nMOTORS  LIMITED  \n \nPresentation  \n   \nAnish Gurav  \n \nGood day and welcome to Tata Motors Q 3 FY24 earnings  call. With me today are PB Balaji, Group CFO, \nTata Motors; Mr. Girish Wagh , Executive Director, Tata Motors ; Mr. Shailesh Chandra, MD, Tata Motors \nPassenger Vehicles Limited and Tata Pass enger Electric Mobility Limited ; Mr. Adrian Mardell, C EO, Jaguar \nLand Rover ; Mr. Richard Molyneux , CFO, Jaguar Land Rover and our colleagues from the Investor relations \nteam.  \n \nToday we plan to walk you through the results presentation followed by Q&A. As a reminder, all \nparticipant lines will be in listen onl y mode and we will be taking questions via  the Teams platform which \nis already open for you to submit your questions. You are requested to mention your name and the name \nof your organization while submitting the question s. \n \nI now hand over to Balaji to tak e this forward.  Over to you, Sir.  \n \n \n \n \n ', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='a78f19f6-134e-4af2-b34d-b5c006d571f8', embedding=None, metadata={'page_label': '3', 'file_name': 'tata.pdf', 'file_path': 'f:\\finance-ai-project\\data\\tata.pdf', 'file_type': 'application/pdf', 'file_size': 807380, 'creation_date': '2024-03-27', 'last_modified_date': '2024-03-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text="                                                                                                        Tata Motors Limited  \nFebruary 2, 2024  \n \n \n \n \nP.B. Balaji  \n \nThanks, Anish. Firstly, welcome all of you for the earnings call. Once again, it  is our pleasure to take you \nthrough the results of the quarter. If I were to leave one message with you as to how we see this quarter, \nwe see this as one of consistent delivery  - six quarters in a row and that gives us tremendous satisfaction \nthat we are executing on our strategies in all our businesses. So that  is probably the broad me ssage I want \nto leave you with. Let us get into the details. Can I have the next slide, please?  \nSafe Harbor Statement, standard, nothing delta here. I think from a product oﬀensive as well as other \ninterventions, it continues to be an intense piece of action for us. We had almost 150 launches happening \nfrom the commercial vehicle side, multiple VCs. Very happy to  say that the plant that we acquired from \nFord, we are calling Sanand 2 has commenced production. In fact, we sold 900 vehicles out of Sanand this \nparticular month. So coming through ve ry nicely and done in a record one year's time period. We also \nintroduced Punch.ev on the advanced Pure EV architecture, which I  am sure Shailesh would love to talk \nabout in his section as well as in Q&A that may come.  And from a focus completely on build ing out the EV \necosystem, signed MOUs for almost 17,000 public charges and also started with the ﬁrst dedicated EV \nshowrooms in India.  On JLR side, the exciting Range Rover Electric has opened. We teased it earlier in the \nquarter and almost 16,000 clients have signed up in the ﬁrst 28 days and we decided that Nitra will \nproduce electric vehicle by 2030 and Defender, of course, continues to win accolades across the board \nwith a new set of awards on What Car? Being the Car of the year there.  Okay, next slide .  \nOn numbers I think before I get into the details of the numbers, one clear call out. I see some confusion \nin the Twitter feed that is there. The TTL sale that we did, the proﬁts from the sale on TTL does not get \nrecognized at a consolidated level because  it is still a subsidiary of Tata Motors and its results are getting \nconsolidated into TML, and therefore, it is only a shareholder -to-shareholder transaction. And therefore, \nin the minority interest, you will see a reduction in the minority interest number one. And number two, it \ngoes via whatever the proﬁt is there is coming via OCI. So the PBT numbers that you see do not include \nTTL proﬁts in the consolidated books. However, in the standalone books, it is a company -to-company \ntransaction in which ca se the proﬁt gets recognized there. That is just for abundant clarity.  So going on to \nthe numbers, on that basis, we had a 25% growth on revenues and an EBIT of 8.3%, up 390 bps and proﬁt \nbefore tax and exceptional items of almost Rs. 7,600 crores in the quarter and a free cash ﬂow of Rs. 6,400 \ncrores. More strikingly, on a YTD basis, just to show the consistency in performance, we  have had about \nRs. 3 lakh crores of revenue growing 32% on a YTD basis so far and we had a PBT before exceptional item \nof Rs. 19,000 crores up almost Rs. 22,000 crores over the previous year same time and almost Rs. 16,000 \ncrores of delta cash has come through. Due to this, t ...
#  Document(id_='0badcbe0-7de3-4d9e-9dc9-3f69170e9431', embedding=None, metadata={'page_label': '4', 'file_name': 'tata.pdf', 'file_path': 'f:\\finance-ai-project\\data\\tata.pdf', 'file_type': 'application/pdf', 'file_size': 807380, 'creation_date': '2024-03-27', 'last_modified_date': '2024-03-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text="                                                                                                        Tata Motors Limited  \nFebruary 2, 2024  \n \n \n \n \nRs. 29,200 crores, of which Tata Motors India is Rs. 3,500 crores and we are conﬁdent that this will go to \nnear zero  by end of this quarter in line with what we had guided. And JLR is now just GBP  1.6 billion, that \nis at Rs. 16,000 crores there, that should also get cleaned out in the coming ﬁnancial year. So we are well \non track to deliver the reduction there. Just as a memo point, the last 12 months, we have reduced our \nnet debt by almost Rs. 28,000 crores , so we are conﬁdent that the next 12 months, this Rs. 29,000 crores \nshould get cleaned out.  Next slide.  \nLet me hand it over to Richard and Adrian. Over to y ou, Richard.  \nRichard Molyneux:  \nOkay, thank you. Yes, I will  take you through the JLR results. So next chart, please. And it’s not often you \nget to present a chart like this, every metric up versus every comparator. And it goes to show that we are \nnow consistently delivering in line with our commitments. So I will talk very quickly through the columns, \nleft to right. So revenue, GBP 7.4 billion in the quarter, GBP 21.1 billion year to date. Those are both \nrecords for JLR. On a quarterly basis, we  are up 22%, and on a year -to-date basis, we are up 35% versus \nprior year.  EBIT margin has now doubled year -over -year. We  are at 8.8% EB IT and 16% EBITDA and pretty \nmuch at 16% EBITDA on a three quarter  cumulative  basis as well. PBT at GBP  627 million is the best Q3 \nwe have had since 2016 , and we are at GBP 1.5 billion just over for the ﬁrst three quarters. Cash ﬂow as \nwell, GBP 626 million in the quarter is the best Q3 cash ﬂow we  have ever had. And we're at GBP 1.4 billion \ncumulative cash ﬂow in nine months. So as I say, it’s not often you get to pre sent charts like that.  Next \nchart.  \n So this chart has some verbatim s. I won't go through it in detail because all the points on it I  will cover in \nthe following charts.  So next chart, please.  \nSo this one shows our wholesales. Wholesales in the quarter at 101,000 units. That's 27% up year -on-year. \nAnd this is the ﬁrst quarter for som e time where we have had wholesales, retails and pro duction all over \n100,000 units.  In terms of the graphs, Range Rover continues to succeed and our production capacity for \nproducing these vehicles also increases. So we were running at 2,900 cars per week  this quarter versus \n2,800 the previous week.  Defender is down, but this is  not any demand issue. We have had some supply \nconstraints on engines which are common between Range Rover and Defender, so we biased the \nproduction towards Range Rover. So those a re supply issues that will come back. There's no demand issue \nwhatsoever in terms of Defender.  Discover y and Jaguar, you can see there. I think interestingly the year -\nto-date numbers, if you look at percent, Range Rover is up 29% year -over -year, Defender is up 46% year -\nover -year. And even those vehicles which are slightly more mature in terms of their life cycle, the Jaguars \nand the Discover ies, are up 9% year -on-year. So even the really mature ones are up year -over -year.  Next \nchart.  \nI won't spend considerable detail on this either, as each region has its own slightly diﬀerent seasonality. I \nthink when you look  ...
#  Document(id_='cdb663c4-d75d-4477-9194-4b4c5f160e1e', embedding=None, metadata={'page_label': '5', 'file_name': 'tata.pdf', 'file_path': 'f:\\finance-ai-project\\data\\tata.pdf', 'file_type': 'application/pdf', 'file_size': 807380, 'creation_date': '2024-03-27', 'last_modified_date': '2024-03-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text="                                                                                                        Tata Motors Limited  \nFebruary 2, 2024  \n \n \n \n \nSo this starts to look at the ﬁnancial walk, it takes PBT from a year ago to the GBP 627 million this quarter. \nObviously, volume and the recovery of our ability to produce is the most signiﬁcant part of the variance. \nHowever, I think there is a little bit of a story to tell in relation to net pricing and contribution costs because \nthose columns look quite diﬀerent to the ones that we presented in prior quarters.  So it is getting a little \nbit more cost ly to acquire customers, particularly as we try to smooth our order bank in the future. So net \npricing is still positive, but not as positive as it has been in previous quarters. However, contribution costs \nare not as bad as they were 12 months ago. This i s largely a result of the fact that as the semiconductor \nsector has come back a bit more towards normality, we are not having to spend anywhere near the \namount of money that we were spending this time last year on broker buys of chips. We've moved much \nmore into long -term, stable, mutually beneﬁcial relationships with chip manufacturers. So that transition \nof having slightly less positive net pricing but more positive material cost is deﬁnitely reﬂective of a change \nin the industry dynamic.  \nStructural costs  are going up. I mentioned beforehand that FME which is our marketing expense and \nselling , that's essentially the same as VME . Those two parts tog ether are us investing more in terms of \ndemand acquisition than we needed to do in the past. Admin is also up.  Over half of that is our digital \ntransformation . FX largely, as would expect it to be, sterling strengthened considerably in the quarter and \nmost of our operational FX was oﬀset by our derivative cover. So that is largely the message here , we are \ndeliveri ng in terms of volume, we're still net price positive and the serious inﬂation pain that we had this \ntime last year is starting to ameliorate.  Next chart .  \nThis takes our PBT to cash, actually GBP 627 million  to GBP 626 million , so it is not a great deal of net \ndiﬀerence. What is important here, I think though, is the cash proﬁt after tax column in the middle there, \nGBP  1.24 billion. That is also a record for JLR. Delivering that level of cash proﬁts does allow us to fund \ninvestment spend ing that is increasing as we move towards the delivery of our new BEV and electrical \narchitectures. So delivery of that is important. Working capital was favorable in the quarter as we had \nhigher volume. But if you note the row below, cumulatively our GBP  1.4 billion year -to-date cash ﬂow, \nonly GBP  0.2 billion of that is due to working capital. Most of it is due to cash proﬁt after tax.  Next chart.  \nInvestment. So investment GBP 862 million for the quarter. Our capitalization rate remains ﬂat at the \nsame rate that it has been for the past two quarters at 63%. I think interesting in here is our engineering \nspend is up 3% quarter -on-quarter, but our capital investment is up 34% quarter -on-quarter. And that \nreﬂects the fact that we are now moving into the ind ustrialization phase of all of our new vehicles. That is \na later phase to engineering, obviously engineering ﬁrst, industrialized second. But it gives the indication \nthat thes ...
# ...
#  Document(id_='e14aa553-df52-48a3-a587-69ecf7627a0e', embedding=None, metadata={'page_label': '20', 'file_name': 'tata.pdf', 'file_path': 'f:\\finance-ai-project\\data\\tata.pdf', 'file_type': 'application/pdf', 'file_size': 807380, 'creation_date': '2024-03-27', 'last_modified_date': '2024-03-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='                                                                                                        Tata Motors Limited  \nFebruary 2, 2024  \n \n \n \n \nTherefore, I think in my view the migration to a higher tonnage node has happened to a large extent. As \nfar as volume projection is concerned for FY 25, as I mentioned, I think we will see some slowdown in Q1 \nand probably H1, a pause. But after I think the  new government comes in place and the investments and \ninfrastructure capex  starts again, I think we will see the next year H2 or Q2 onwards we will see a YoY \ngrowth again. Balaji?  \nPB Balaji  \nYeah. Girish, the next one again with you. This is on small co mmercial vehicles from Amyn Pirani. Your \nIndia SCV market share has been impacted by weakness in the category of less than 2 tons. However, in \nthe categories which are doing well, your market share remains quite low. Are there any product \ninterventions tha t we can expect here?  \nGirish Wagh  \nRight. So let me answer it on two fronts. First of all, I think your assessment of the situation there is right. \nSee ﬁrst of all, in SCV pickup, as we have done in other businesses, we are focusing on improving our \nﬁnancia ls and unit economics very aggressively and I think I am happy that we have actually made a very \ngood progress. It is a transformation that we are on to and  we are committe d to it.  \nNow, coming to the volumes. Yes, the small vehicles has two categories, the  SCVs and the pickups. And as \nyou rightly put up, I think the SCVs are facing a challenge because the overall segment is declining. The \nmain reason for this is with BS6 Phase 1 and BS6 Phase 2, there has been a signiﬁcant increase in the prices \nof the vehi cles. And as we have seen globally, in both cars as well as commercial vehicles, I think with such \nkind of an increase, the smallest segment actually starts facing pressure. I think to address this, what we \nhave done is, we  have actually launched the ACE i n gasoline variant, which actually comes at BS4 prices \nand BS4 total cost of ownership.  So it is a completely new value proposition and we see a continuously \nincreasing traction for this. So we are trying to build good traction for this product, improving the \nconsideration amongst the customers, because it is gasoline and gasoline is seen as not suitable for \ncommercial applicat ion. So this is the ﬁrst thing.  Second thing, we are also facing a lot of ﬁnancing \nchallenges for the smallest commercial vehicles, post COVID especially. And the ﬁrst time users are ﬁnding \nit diﬃcult to get higher loan -to-value ratios. Therefore, the down payment requirements are higher. And \nwhile we do get very good leads, I think the conversion rates are currently low. So we are wor king with \nthe financiers  to improve the availability of ﬁnancing here. And third, of course, as Balaji mentioned, I \nthink with Tata Motor Finance coming back on track and being very healthy, I think we are working with \nthem to see how we can start helping t he ﬁrst -time users once again. So these are the things that we are \ndoing in small commercial vehicles to increase its salience once again.  \nComing to pickups, I think your question is whether any product intervention is going to happen here. So \nin pickups, we believe that we actually have a very good product portfolio. In the intra -family, we have a ...
#  Document(id_='1ccdb50d-babc-44bd-89e1-3fa624480589', embedding=None, metadata={'page_label': '21', 'file_name': 'tata.pdf', 'file_path': 'f:\\finance-ai-project\\data\\tata.pdf', 'file_type': 'application/pdf', 'file_size': 807380, 'creation_date': '2024-03-27', 'last_modified_date': '2024-03-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text="                                                                                                        Tata Motors Limited  \nFebruary 2, 2024  \n \n \n \n \nSCV and pickup category, we've always seen that there is a lot of brand loyalty becaus e when customers \nbuy this vehicle, it is a signiﬁcant purchase for them and their earning actually depends on this. So \ngenerally they tend to depend on a vehicle which has been there in the market for quite some time, and \ntherefore, any new vehicle takes t ime to get established. So our focus here has been to improve \nawareness and be  in the consideration set and start creating a brand pull. Towards this, we are also \nworking on inﬂuencer ecosystem to ensure that they talk positive about these products and als o on \nmaking network eﬀective and proﬁtable for this particular type of business. So we are also, therefore, \ncreating a separate network from the heavy commercial vehicle business. So I think these are the actions \nthat we are taking on the small commercial vehicle and the pickup business, Balaji.  \nPB Balaji  \nSo, just to hold it with you for a minute, I think if I look at Gunjan's questions, most of it we have answered. \nThere's one on in small commercial vehicle, is there any impact of electric three -wheelers o n your SCV \nportfolio?  \nGirish Wagh  \nSo if you look at the electric three -wheelers, bulk of those are actually getting sold in the passenger \napplication. The salience of the goods electric three -vehicles is pretty low. But initially, yes, I think the \ncustomer s were comparing this with ACE EV. And gradually, what I think there has been a realization that \nACE EV is actually far better on performance, far better on reliability, and therefore far better on \nproﬁtability. And I think, we had an issue about ﬁnancing,  again, in ACE EV and what should be the end -\nof-life value that should be considered. So I think here we have worked with the ﬁnanciers, we have come \nup with the ﬁrst in the industry, seven -year battery warranty, which has helped to actually give very \nattractive ﬁnancing schemes, as a  result of which we see very good traction for ACE EV. So in a nutshell, I \nthink electric three -wheelers, for some time, goods carrier did show some impact on this, but not to such \nan extent. Now, I think the customers are comi ng back to the ICE portfolio or otherwise the ACE EV. Balaji?  \nPB Balaji  \nYeah. Thanks, Girish. Shailesh, coming your way. When is Curvv commercial launch planned? One. And if \nyou can comment, if possible, on other product launches that you're planning this year? And how's the \nPunch.ev  - How has it picked up and how's the order intake there? I think ACE EV, you already answered.  \nShailesh Chandra  \nSo if we talk about the full calendar year 2024, so this calendar year will see three electric vehicle launches, \none Punch EV, which happened already in Jan. And I will  talk about the order intake of Punch EV at last. \nThe second would be Curvv, which will come in second quarter of the ﬁnancial year 2025. And the third \nwould be Harrier EV. The ICE Curvv would get launch ed, say, three to four months after the launch of the \nEV version. So that's what has been plan ned for the calendar year 2024. As far as Punch is concerned, you \nknow, this was our ﬁrst product on the Pure EV architecture, which is “acti.ev ”. Solid product, un ...
#  Document(id_='01edbe4d-fd87-4e15-8424-1ec5886809e3', embedding=None, metadata={'page_label': '22', 'file_name': 'tata.pdf', 'file_path': 'f:\\finance-ai-project\\data\\tata.pdf', 'file_type': 'application/pdf', 'file_size': 807380, 'creation_date': '2024-03-27', 'last_modified_date': '2024-03-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text="                                                                                                        Tata Motors Limited  \nFebruary 2, 2024  \n \n \n \n \nlakh, giving 400 kilometer range was expected to create lot of demand for us and that is what we are \nseeing. Very strong demand and bookings that we have received for the product, and we are ramping up \nour capacity also. Can't share the numbers becau se we have not been sharing booking numbers for the \nsimple reason that that should not create any kind of concern for the customers in terms of their waiting \nperiod and all. So the idea is that we take into account the bookings that have come and ramp up t he \nproduction as fast as possible.  \nPB Balaji  \nYeah. Thank you. And moving to Richard, this is probably coming your way. Proportion of buyers who \nbought Jaguar and Land Rover for the ﬁrst time and how many already own a Jaguar or LR, has there been \nany changes to these  numbers f rom 2019? Would you track this?  \nRichard Molyneux  \nI don't have that info rmation in front of me. I am not aware of any material change in our mix of buyers \nbetween loyal and conquest . \nPB Balaji  \nOkay, thank you. The other one coming your way, Girish. I think you touched upon a little bit, maybe \nworthwhile given a number of quest ions that have come. With the payment security mechanism now \nthere in place for EV buses, would you be participating more aggressively, are there any discussion with \nthe government, probably buses that are being made locally, those kind of things?  \n Girish Wagh  \nYeah. So I think two things here. First is I think we have been the OEM which started deploying the buses \nafter winning the ﬁrst tender of C ESL, which we had built very aggressively with an objective of making \nthe government's intention successful of electriﬁcation. And you know, as I explained, we have actually \ngood amount of experience under our belt now, which gives us very good data to decide what we should \nbe quoting. Now, coming to payment security mechanism, actually, we must appreciate the open ness of \nthe government to listen to the industry and accept this requirement. So this payment security mechanism \nis more or less agreed upon. I think there are a few things that are remaining which need to be sorted out \nwhich will ensure that our balance s heet remains lighter and which will help us to get into this business \nvery, very aggressively. So I think good experience under the belt, product range ready. The scheme is \nbecoming what we need. Just a last mile thing that needs to be addressed, and we'll  be there.  \nPB Balaji  \nSo one more coming your way, Shailesh. Punch EV, Nexon EV, do you see an overlap and is there any \ncannibalization risk that you see?  \n ", start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='5584a30e-ac8b-4a1a-ba27-01adfd10ab8f', embedding=None, metadata={'page_label': '23', 'file_name': 'tata.pdf', 'file_path': 'f:\\finance-ai-project\\data\\tata.pdf', 'file_type': 'application/pdf', 'file_size': 807380, 'creation_date': '2024-03-27', 'last_modified_date': '2024-03-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text="                                                                                                        Tata Motors Limited  \nFebruary 2, 2024  \n \n \n \n \nShailesh Chandra  \nYou know, there's always some cannibalization risks in adjacent segments and that is okay for us. But \nthese are two very distinct segments at very distinct price points. If you compare a 450 -kilometer Nexon \nthat is costing around Rs. 18 lakh to Rs. 19 lakhs as a weighted average price, whereas Punch is with the \nsimilar kind of ranges, bein g priced between Rs. 13 lakh to Rs. 15 lakh, so there's very less chance of \ncannibalization, a very diﬀerent customer segment as far as EV is concerned. So I don't see a big risk of \ncannibalization and that's what we have been observing in Jan uary  also pos t the launch.  \nPB Balaji  \nYeah. Thank you. Thanks, Shailesh. I think with this, we have come to the end of the questions. I think we \nhave covered most of the questions that people are very keen to understand. So if there's anything that's \nstill left, feel fr ee to contact our Investor Relations team, we will be mor e than happy to respond to you.  \nWith this, I  woul d like to draw this results call to a close. Thanks all for your time and patience in going \nthrough the results. Look forward to catching up with you.  Thank you. Bye -bye and thanks, guys who are \non the call. Thanks.  \n ", start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n')]

# %%
system_prompt="""
You are a Q&A assistant. Your goal is to answer questions as
accurately as possible based on the instructions and context provided.
"""
## Default format supportable by LLama2
query_wrapper_prompt=SimpleInputPrompt("<|USER|>{query_str}<|ASSISTANT|>")

# %%
# !huggingface-cli login
# Out:
# ^C

# %%
import torch

llm = HuggingFaceLLM(
    context_window=4096,
    max_new_tokens=256,
    generate_kwargs={"temperature": 0.0, "do_sample": False},
    system_prompt=system_prompt,
    query_wrapper_prompt=query_wrapper_prompt,
    tokenizer_name="google/gemma-2b-it",
    model_name="google/gemma-2b-it",
    device_map="auto",
    # uncomment this if using CUDA to reduce memory usage
    model_kwargs={"torch_dtype": torch.float16}# , "load_in_8bit":True}
)
# Out:
# config.json:   0%|          | 0.00/627 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/13.5k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 3
#       1 import torch
# ----> 3 llm = HuggingFaceLLM(
#       4     context_window=4096,
#       5     max_new_tokens=256,
#       6     generate_kwargs={"temperature": 0.0, "do_sample": False},
#       7     system_prompt=system_prompt,
#       8     query_wrapper_prompt=query_wrapper_prompt,
#       9     tokenizer_name="google/gemma-2b-it",
#      10     model_name="google/gemma-2b-it",
#      11     device_map="auto",
#      12     # uncomment this if using CUDA to reduce memory usage
#      13     model_kwargs={"torch_dtype": torch.float16}# , "load_in_8bit":True}
#      14 )
#
# File f:\finance-ai-project\finance_env\lib\site-packages\llama_index\llms\huggingface\base.py:161, in HuggingFaceLLM.__init__(self, context_window, max_new_tokens, query_wrapper_prompt, tokenizer_name, model_name, model, tokenizer, device_map, stopping_ids, tokenizer_kwargs, tokenizer_outputs_to_remove, model_kwargs, generate_kwargs, is_chat_model, callback_manager, system_prompt, messages_to_prompt, completion_to_prompt, pydantic_program_mode, output_parser)
#     159 """Initialize params."""
#     160 model_kwargs = model_kwargs or {}
# --> 161 self._model = model or AutoModelForCausalLM.from_pretrained(
#     162     model_name, device_map=device_map, **model_kwargs
#     163 )
#     165 # check context_window
#     166 config_dict = self._model.config.to_dict()
#
# File f:\finance-ai-project\finance_env\lib\site-packages\transformers\models\auto\auto_factory.py:563, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     561 elif type(config) in cls._model_mapping.keys():
#     562     model_class = _get_model_class(config, cls._model_mapping)
# --> 563     return model_class.from_pretrained(
#     564         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     565     )
#     566 raise ValueError(
#     567     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     568     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping.keys())}."
#     569 )
#
# File f:\finance-ai-project\finance_env\lib\site-packages\transformers\modeling_utils.py:3290, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    3287 # We'll need to download and cache each checkpoint shard if the checkpoint is sharded.
#    3288 if is_sharded:
#    3289     # rsolved_archive_file becomes a list of files that point to the different checkpoint shards in this case.
# -> 3290     resolved_archive_file, sharded_metadata = get_checkpoint_shard_files(
#    3291         pretrained_model_name_or_path,
#    3292         resolved_archive_file,
#    3293         cache_dir=cache_dir,
#    3294         force_download=force_download,
#    3295         proxies=proxies,
#    3296         resume_download=resume_download,
#    3297         local_files_only=local_files_only,
#    3298         token=token,
#    3299         user_agent=user_agent,
#    3300         revision=revision,
#    3301         subfolder=subfolder,
#    3302         _commit_hash=commit_hash,
#    3303     )
#    3305 if (
#    3306     is_safetensors_available()
#    3307     and isinstance(resolved_archive_file, str)
#    3308     and resolved_archive_file.endswith(".safetensors")
#    3309 ):
#    3310     with safe_open(resolved_archive_file, framework="pt") as f:
#
# File f:\finance-ai-project\finance_env\lib\site-packages\transformers\utils\hub.py:1038, in get_checkpoint_shard_files(pretrained_model_name_or_path, index_filename, cache_dir, force_download, proxies, resume_download, local_files_only, token, user_agent, revision, subfolder, _commit_hash, **deprecated_kwargs)
#    1035 for shard_filename in tqdm(shard_filenames, desc="Downloading shards", disable=not show_progress_bar):
#    1036     try:
#    1037         # Load from URL
# -> 1038         cached_filename = cached_file(
#    1039             pretrained_model_name_or_path,
#    1040             shard_filename,
#    1041             cache_dir=cache_dir,
#    1042             force_download=force_download,
#    1043             proxies=proxies,
#    1044             resume_download=resume_download,
#    1045             local_files_only=local_files_only,
#    1046             token=token,
#    1047             user_agent=user_agent,
#    1048             revision=revision,
#    1049             subfolder=subfolder,
#    1050             _commit_hash=_commit_hash,
#    1051         )
#    1052     # We have already dealt with RepositoryNotFoundError and RevisionNotFoundError when getting the index, so
#    1053     # we don't have to catch them here.
#    1054     except EntryNotFoundError:
#
# File f:\finance-ai-project\finance_env\lib\site-packages\transformers\utils\hub.py:398, in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     395 user_agent = http_user_agent(user_agent)
#     396 try:
#     397     # Load from URL or cache if already cached
# --> 398     resolved_file = hf_hub_download(
#     399         path_or_repo_id,
#     400         filename,
#     401         subfolder=None if len(subfolder) == 0 else subfolder,
#     402         repo_type=repo_type,
#     403         revision=revision,
#     404         cache_dir=cache_dir,
#     405         user_agent=user_agent,
#     406         force_download=force_download,
#     407         proxies=proxies,
#     408         resume_download=resume_download,
#     409         token=token,
#     410         local_files_only=local_files_only,
#     411     )
#     412 except GatedRepoError as e:
#     413     resolved_file = _get_cache_file_to_return(path_or_repo_id, full_filename, cache_dir, revision)
#
# File f:\finance-ai-project\finance_env\lib\site-packages\huggingface_hub\utils\_validators.py:118, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     115 if check_use_auth_token:
#     116     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 118 return fn(*args, **kwargs)
#
# File f:\finance-ai-project\finance_env\lib\site-packages\huggingface_hub\file_download.py:1457, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, local_dir_use_symlinks, user_agent, force_download, force_filename, proxies, etag_timeout, resume_download, token, local_files_only, legacy_cache_layout, endpoint)
#    1454         if local_dir is not None:
#    1455             _check_disk_space(expected_size, local_dir)
# -> 1457     http_get(
#    1458         url_to_download,
#    1459         temp_file,
#    1460         proxies=proxies,
#    1461         resume_size=resume_size,
#    1462         headers=headers,
#    1463         expected_size=expected_size,
#    1464     )
#    1466 if local_dir is None:
#    1467     logger.debug(f"Storing {url} in cache at {blob_path}")
#
# File f:\finance-ai-project\finance_env\lib\site-packages\huggingface_hub\file_download.py:524, in http_get(url, temp_file, proxies, resume_size, headers, expected_size, _nb_retries)
#     522 new_resume_size = resume_size
#     523 try:
# --> 524     for chunk in r.iter_content(chunk_size=DOWNLOAD_CHUNK_SIZE):
#     525         if chunk:  # filter out keep-alive new chunks
#     526             progress.update(len(chunk))
#
# File f:\finance-ai-project\finance_env\lib\site-packages\requests\models.py:816, in Response.iter_content.<locals>.generate()
#     814 if hasattr(self.raw, "stream"):
#     815     try:
# --> 816         yield from self.raw.stream(chunk_size, decode_content=True)
#     817     except ProtocolError as e:
#     818         raise ChunkedEncodingError(e)
#
# File f:\finance-ai-project\finance_env\lib\site-packages\urllib3\response.py:1043, in HTTPResponse.stream(self, amt, decode_content)
#    1041 else:
#    1042     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
# -> 1043         data = self.read(amt=amt, decode_content=decode_content)
#    1045         if data:
#    1046             yield data
#
# File f:\finance-ai-project\finance_env\lib\site-packages\urllib3\response.py:935, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     932     if len(self._decoded_buffer) >= amt:
#     933         return self._decoded_buffer.get(amt)
# --> 935 data = self._raw_read(amt)
#     937 flush_decoder = amt is None or (amt != 0 and not data)
#     939 if not data and len(self._decoded_buffer) == 0:
#
# File f:\finance-ai-project\finance_env\lib\site-packages\urllib3\response.py:862, in HTTPResponse._raw_read(self, amt, read1)
#     859 fp_closed = getattr(self._fp, "closed", False)
#     861 with self._error_catcher():
# --> 862     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#     863     if amt is not None and amt != 0 and not data:
#     864         # Platform-specific: Buggy versions of Python.
#     865         # Close the connection when no data is returned
#    (...)
#     870         # not properly close the connection in all cases. There is
#     871         # no harm in redundantly calling close.
#     872         self._fp.close()
#
# File f:\finance-ai-project\finance_env\lib\site-packages\urllib3\response.py:845, in HTTPResponse._fp_read(self, amt, read1)
#     842     return self._fp.read1(amt) if amt is not None else self._fp.read1()
#     843 else:
#     844     # StringIO doesn't like amt=None
# --> 845     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:466, in HTTPResponse.read(self, amt)
#     463 if self.length is not None and amt > self.length:
#     464     # clip the read to the "end of response"
#     465     amt = self.length
# --> 466 s = self.fp.read(amt)
#     467 if not s and amt:
#     468     # Ideally, we would raise IncompleteRead if the content-length
#     469     # wasn't satisfied, but it might break compatibility.
#     470     self._close_conn()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File ~\AppData\Local\Programs\Python\Python310\lib\ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
from langchain.embeddings.huggingface import HuggingFaceEmbeddings
from llama_index.core import ServiceContext
from llama_index.embeddings.langchain import LangchainEmbedding

embed_model=LangchainEmbedding(
    HuggingFaceEmbeddings(model_name="sentence-transformers/all-mpnet-base-v2"))
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
service_context=ServiceContext.from_defaults(
    chunk_size=1024,
    llm=llm,
    embed_model=embed_model
)
# Out:
# C:\Users\jayga\AppData\Local\Temp\ipykernel_15668\2250285859.py:1: DeprecationWarning: Call to deprecated class method from_defaults. (ServiceContext is deprecated, please use `llama_index.settings.Settings` instead.) -- Deprecated since version 0.10.0.
#   service_context=ServiceContext.from_defaults(

# %%
service_context
# Out:
# ServiceContext(llm_predictor=LLMPredictor(system_prompt=None, query_wrapper_prompt=None, pydantic_program_mode=<PydanticProgramMode.DEFAULT: 'default'>), prompt_helper=PromptHelper(context_window=4096, num_output=256, chunk_overlap_ratio=0.1, chunk_size_limit=None, separator=' '), embed_model=LangchainEmbedding(model_name='sentence-transformers/all-mpnet-base-v2', embed_batch_size=10, callback_manager=<llama_index.core.callbacks.base.CallbackManager object at 0x0000018B70AA2770>), transformations=[SentenceSplitter(include_metadata=True, include_prev_next_rel=True, callback_manager=<llama_index.core.callbacks.base.CallbackManager object at 0x0000018B70AA2770>, id_func=<function default_id_func at 0x0000018B65BFC160>, chunk_size=1024, chunk_overlap=200, separator=' ', paragraph_separator='\n\n\n', secondary_chunking_regex='[^,.;。？！]+[,.;。？！]?')], llama_logger=<llama_index.core.service_context_elements.llama_logger.LlamaLogger object at 0x0000018B748EFFA0>, callback_manager=<llama_index.core.callbacks.base.CallbackManager object at 0x0000018B70AA2770>)

# %%
index=VectorStoreIndex.from_documents(documents,service_context=service_context)

# %%
index

# %%
query_engine=index.as_query_engine()

# %%
response=query_engine.query("what is the capex spend for tata this year?")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 response=query_engine.query("what is the capex spend for tata this year?")
#
# File f:\finance-ai-project\finance_env\lib\site-packages\llama_index\core\instrumentation\dispatcher.py:100, in Dispatcher.span.<locals>.wrapper(*args, **kwargs)
#      98 self.span_enter(*args, id=id, **kwargs)
#      99 try:
# --> 100     result = func(*args, **kwargs)
#     101 except Exception as e:
#     102     self.span_drop(*args, id=id, err=e, **kwargs)
#
# File f:\finance-ai-project\finance_env\lib\site-packages\llama_index\core\base\base_query_engine.py:51, in BaseQueryEngine.query(self, str_or_query_bundle)
#      49     if isinstance(str_or_query_bundle, str):
#      50         str_or_query_bundle = QueryBundle(str_or_query_bundle)
# ---> 51     query_result = self._query(str_or_query_bundle)
#      52 dispatcher.event(QueryEndEvent())
#      53 return query_result
#
# File f:\finance-ai-project\finance_env\lib\site-packages\llama_index\core\instrumentation\dispatcher.py:100, in Dispatcher.span.<locals>.wrapper(*args, **kwargs)
#      98 self.span_enter(*args, id=id, **kwargs)
#      99 try:
# --> 100     result = func(*args, **kwargs)
#     101 except Exception as e:
#     102     self.span_drop(*args, id=id, err=e, **kwargs)
#
# File f:\finance-ai-project\finance_env\lib\site-packages\llama_index\core\query_engine\retriever_query_engine.py:190, in RetrieverQueryEngine._query(self, query_bundle)
#     186 with self.callback_manager.event(
#     187     CBEventType.QUERY, payload={EventPayload.QUERY_STR: query_bundle.query_str}
#     188 ) as query_event:
#     189     nodes = self.retrieve(query_bundle)
# --> 190     response = self._response_synthesizer.synthesize(
#     191         query=query_bundle,
#     192         nodes=nodes,
#     193     )
#     194     query_event.on_end(payload={EventPayload.RESPONSE: response})
#     196 return response
#
# File f:\finance-ai-project\finance_env\lib\site-packages\llama_index\core\instrumentation\dispatcher.py:100, in Dispatcher.span.<locals>.wrapper(*args, **kwargs)
#      98 self.span_enter(*args, id=id, **kwargs)
#      99 try:
# --> 100     result = func(*args, **kwargs)
#     101 except Exception as e:
#     102     self.span_drop(*args, id=id, err=e, **kwargs)
#
# File f:\finance-ai-project\finance_env\lib\site-packages\llama_index\core\response_synthesizers\base.py:228, in BaseSynthesizer.synthesize(self, query, nodes, additional_source_nodes, **response_kwargs)
#     223     query = QueryBundle(query_str=query)
#     225 with self._callback_manager.event(
#     226     CBEventType.SYNTHESIZE, payload={EventPayload.QUERY_STR: query.query_str}
#     227 ) as event:
# --> 228     response_str = self.get_response(
#     229         query_str=query.query_str,
#     230         text_chunks=[
#     231             n.node.get_content(metadata_mode=MetadataMode.LLM) for n in nodes
#     232         ],
#     233         **response_kwargs,
#     234     )
#     236     additional_source_nodes = additional_source_nodes or []
#     237     source_nodes = list(nodes) + list(additional_source_nodes)
#
# File f:\finance-ai-project\finance_env\lib\site-packages\llama_index\core\instrumentation\dispatcher.py:100, in Dispatcher.span.<locals>.wrapper(*args, **kwargs)
#      98 self.span_enter(*args, id=id, **kwargs)
#      99 try:
# --> 100     result = func(*args, **kwargs)
#     101 except Exception as e:
#     102     self.span_drop(*args, id=id, err=e, **kwargs)
#
# File f:\finance-ai-project\finance_env\lib\site-packages\llama_index\core\response_synthesizers\compact_and_refine.py:43, in CompactAndRefine.get_response(self, query_str, text_chunks, prev_response, **response_kwargs)
#      39 # use prompt helper to fix compact text_chunks under the prompt limitation
#      40 # TODO: This is a temporary fix - reason it's temporary is that
#      41 # the refine template does not account for size of previous answer.
#      42 new_texts = self._make_compact_text_chunks(query_str, text_chunks)
# ---> 43 return super().get_response(
#      44     query_str=query_str,
#      45     text_chunks=new_texts,
#      46     prev_response=prev_response,
#      47     **response_kwargs,
#      48 )
#
# File f:\finance-ai-project\finance_env\lib\site-packages\llama_index\core\instrumentation\dispatcher.py:100, in Dispatcher.span.<locals>.wrapper(*args, **kwargs)
#      98 self.span_enter(*args, id=id, **kwargs)
#      99 try:
# --> 100     result = func(*args, **kwargs)
#     101 except Exception as e:
#     102     self.span_drop(*args, id=id, err=e, **kwargs)
#
# File f:\finance-ai-project\finance_env\lib\site-packages\llama_index\core\response_synthesizers\refine.py:181, in Refine.get_response(self, query_str, text_chunks, prev_response, **response_kwargs)
#     177 for text_chunk in text_chunks:
#     178     if prev_response is None:
#     179         # if this is the first chunk, and text chunk already
#     180         # is an answer, then return it
# --> 181         response = self._give_response_single(
#     182             query_str, text_chunk, **response_kwargs
#     183         )
#     184     else:
#     185         # refine response if possible
#     186         response = self._refine_response_single(
#     187             prev_response, query_str, text_chunk, **response_kwargs
#     188         )
#
# File f:\finance-ai-project\finance_env\lib\site-packages\llama_index\core\response_synthesizers\refine.py:236, in Refine._give_response_single(self, query_str, text_chunk, **response_kwargs)
#     232 if response is None and not self._streaming:
#     233     try:
#     234         structured_response = cast(
#     235             StructuredRefineResponse,
# --> 236             program(
#     237                 context_str=cur_text_chunk,
#     238                 **response_kwargs,
#     239             ),
#     240         )
#     241         query_satisfied = structured_response.query_satisfied
#     242         if query_satisfied:
#
# File f:\finance-ai-project\finance_env\lib\site-packages\llama_index\core\response_synthesizers\refine.py:84, in DefaultRefineProgram.__call__(self, *args, **kwds)
#      82     answer = answer.json()
#      83 else:
# ---> 84     answer = self._llm.predict(
#      85         self._prompt,
#      86         **kwds,
#      87     )
#      88 return StructuredRefineResponse(answer=answer, query_satisfied=True)
#
# File f:\finance-ai-project\finance_env\lib\site-packages\llama_index\core\instrumentation\dispatcher.py:100, in Dispatcher.span.<locals>.wrapper(*args, **kwargs)
#      98 self.span_enter(*args, id=id, **kwargs)
#      99 try:
# --> 100     result = func(*args, **kwargs)
#     101 except Exception as e:
#     102     self.span_drop(*args, id=id, err=e, **kwargs)
#
# File f:\finance-ai-project\finance_env\lib\site-packages\llama_index\core\llms\llm.py:415, in LLM.predict(self, prompt, **prompt_args)
#     413 else:
#     414     formatted_prompt = self._get_prompt(prompt, **prompt_args)
# --> 415     response = self.complete(formatted_prompt, formatted=True)
#     416     output = response.text
#     418 dispatcher.event(LLMPredictEndEvent())
#
# File f:\finance-ai-project\finance_env\lib\site-packages\llama_index\core\llms\callbacks.py:294, in llm_completion_callback.<locals>.wrap.<locals>.wrapped_llm_predict(_self, *args, **kwargs)
#     278 dispatcher.event(
#     279     LLMCompletionStartEvent(
#     280         model_dict=_self.to_dict(),
#    (...)
#     283     )
#     284 )
#     285 event_id = callback_manager.on_event_start(
#     286     CBEventType.LLM,
#     287     payload={
#    (...)
#     291     },
#     292 )
# --> 294 f_return_val = f(_self, *args, **kwargs)
#     295 if isinstance(f_return_val, Generator):
#     296     # intercept the generator and add a callback to the end
#     297     def wrapped_gen() -> CompletionResponseGen:
#
# File f:\finance-ai-project\finance_env\lib\site-packages\llama_index\llms\huggingface\base.py:281, in HuggingFaceLLM.complete(self, prompt, formatted, **kwargs)
#     278     if key in inputs:
#     279         inputs.pop(key, None)
# --> 281 tokens = self._model.generate(
#     282     **inputs,
#     283     max_new_tokens=self.max_new_tokens,
#     284     stopping_criteria=self._stopping_criteria,
#     285     **self.generate_kwargs,
#     286 )
#     287 completion_tokens = tokens[0][inputs["input_ids"].size(1) :]
#     288 completion = self._tokenizer.decode(completion_tokens, skip_special_tokens=True)
#
# File f:\finance-ai-project\finance_env\lib\site-packages\torch\utils\_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File f:\finance-ai-project\finance_env\lib\site-packages\transformers\generation\utils.py:1527, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    1509     result = self.assisted_decoding(
#    1510         input_ids,
#    1511         candidate_generator=candidate_generator,
#    (...)
#    1523         **model_kwargs,
#    1524     )
#    1525 if generation_mode == GenerationMode.GREEDY_SEARCH:
#    1526     # 11. run greedy search
# -> 1527     result = self._greedy_search(
#    1528         input_ids,
#    1529         logits_processor=prepared_logits_processor,
#    1530         stopping_criteria=prepared_stopping_criteria,
#    1531         pad_token_id=generation_config.pad_token_id,
#    1532         eos_token_id=generation_config.eos_token_id,
#    1533         output_scores=generation_config.output_scores,
#    1534         output_logits=generation_config.output_logits,
#    1535         return_dict_in_generate=generation_config.return_dict_in_generate,
#    1536         synced_gpus=synced_gpus,
#    1537         streamer=streamer,
#    1538         **model_kwargs,
#    1539     )
#    1541 elif generation_mode == GenerationMode.CONTRASTIVE_SEARCH:
#    1542     if not model_kwargs["use_cache"]:
#
# File f:\finance-ai-project\finance_env\lib\site-packages\transformers\generation\utils.py:2411, in GenerationMixin._greedy_search(self, input_ids, logits_processor, stopping_criteria, max_length, pad_token_id, eos_token_id, output_attentions, output_hidden_states, output_scores, output_logits, return_dict_in_generate, synced_gpus, streamer, **model_kwargs)
#    2408 model_inputs = self.prepare_inputs_for_generation(input_ids, **model_kwargs)
#    2410 # forward pass to get next token
# -> 2411 outputs = self(
#    2412     **model_inputs,
#    2413     return_dict=True,
#    2414     output_attentions=output_attentions,
#    2415     output_hidden_states=output_hidden_states,
#    2416 )
#    2418 if synced_gpus and this_peer_finished:
#    2419     continue  # don't waste resources running the code we don't need
#
# File f:\finance-ai-project\finance_env\lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File f:\finance-ai-project\finance_env\lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File f:\finance-ai-project\finance_env\lib\site-packages\accelerate\hooks.py:166, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     164         output = module._old_forward(*args, **kwargs)
#     165 else:
# --> 166     output = module._old_forward(*args, **kwargs)
#     167 return module._hf_hook.post_forward(module, output)
#
# File f:\finance-ai-project\finance_env\lib\site-packages\transformers\models\llama\modeling_llama.py:1196, in LlamaForCausalLM.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#    1193 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#    1195 # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# -> 1196 outputs = self.model(
#    1197     input_ids=input_ids,
#    1198     attention_mask=attention_mask,
#    1199     position_ids=position_ids,
#    1200     past_key_values=past_key_values,
#    1201     inputs_embeds=inputs_embeds,
#    1202     use_cache=use_cache,
#    1203     output_attentions=output_attentions,
#    1204     output_hidden_states=output_hidden_states,
#    1205     return_dict=return_dict,
#    1206     cache_position=cache_position,
#    1207 )
#    1209 hidden_states = outputs[0]
#    1210 if self.config.pretraining_tp > 1:
#
# File f:\finance-ai-project\finance_env\lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File f:\finance-ai-project\finance_env\lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File f:\finance-ai-project\finance_env\lib\site-packages\transformers\models\llama\modeling_llama.py:1016, in LlamaModel.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#    1005     layer_outputs = self._gradient_checkpointing_func(
#    1006         decoder_layer.__call__,
#    1007         hidden_states,
#    (...)
#    1013         cache_position,
#    1014     )
#    1015 else:
# -> 1016     layer_outputs = decoder_layer(
#    1017         hidden_states,
#    1018         attention_mask=causal_mask,
#    1019         position_ids=position_ids,
#    1020         past_key_value=past_key_values,
#    1021         output_attentions=output_attentions,
#    1022         use_cache=use_cache,
#    1023         cache_position=cache_position,
#    1024     )
#    1026 hidden_states = layer_outputs[0]
#    1028 if use_cache:
#
# File f:\finance-ai-project\finance_env\lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File f:\finance-ai-project\finance_env\lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File f:\finance-ai-project\finance_env\lib\site-packages\accelerate\hooks.py:166, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     164         output = module._old_forward(*args, **kwargs)
#     165 else:
# --> 166     output = module._old_forward(*args, **kwargs)
#     167 return module._hf_hook.post_forward(module, output)
#
# File f:\finance-ai-project\finance_env\lib\site-packages\transformers\models\llama\modeling_llama.py:739, in LlamaDecoderLayer.forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache, cache_position, **kwargs)
#     736 hidden_states = self.input_layernorm(hidden_states)
#     738 # Self Attention
# --> 739 hidden_states, self_attn_weights, present_key_value = self.self_attn(
#     740     hidden_states=hidden_states,
#     741     attention_mask=attention_mask,
#     742     position_ids=position_ids,
#     743     past_key_value=past_key_value,
#     744     output_attentions=output_attentions,
#     745     use_cache=use_cache,
#     746     cache_position=cache_position,
#     747     **kwargs,
#     748 )
#     749 hidden_states = residual + hidden_states
#     751 # Fully Connected
#
# File f:\finance-ai-project\finance_env\lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File f:\finance-ai-project\finance_env\lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File f:\finance-ai-project\finance_env\lib\site-packages\accelerate\hooks.py:166, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     164         output = module._old_forward(*args, **kwargs)
#     165 else:
# --> 166     output = module._old_forward(*args, **kwargs)
#     167 return module._hf_hook.post_forward(module, output)
#
# File f:\finance-ai-project\finance_env\lib\site-packages\transformers\models\llama\modeling_llama.py:637, in LlamaSdpaAttention.forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache, cache_position)
#     634 bsz, q_len, _ = hidden_states.size()
#     636 query_states = self.q_proj(hidden_states)
# --> 637 key_states = self.k_proj(hidden_states)
#     638 value_states = self.v_proj(hidden_states)
#     640 query_states = query_states.view(bsz, q_len, self.num_heads, self.head_dim).transpose(1, 2)
#
# File f:\finance-ai-project\finance_env\lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File f:\finance-ai-project\finance_env\lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File f:\finance-ai-project\finance_env\lib\site-packages\accelerate\hooks.py:166, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     164         output = module._old_forward(*args, **kwargs)
#     165 else:
# --> 166     output = module._old_forward(*args, **kwargs)
#     167 return module._hf_hook.post_forward(module, output)
#
# File f:\finance-ai-project\finance_env\lib\site-packages\torch\nn\modules\linear.py:116, in Linear.forward(self, input)
#     115 def forward(self, input: Tensor) -> Tensor:
# --> 116     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
print(response)
# Out:
# Attention is a powerful tool in NLP, but it is not the only thing you need to build a successful model. While attention mechanisms like the one described in the passage can help the model focus on relevant parts of the input, they do not address other important aspects of language processing, such as syntax and semantics. To build a truly robust NLP model, you will need to incorporate a variety of techniques, including attention, as well as other types of neural network layers and traditional NLP methods.

# %%
response=query_engine.query("what is YOLO?")
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:381: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:386: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(

# %%
print(response)
# Out:
# YOLO is a real-time object detection system that uses a single neural network to predict bounding boxes and class probabilities directly from full images. It is simple, fast, and achieves high performance on object detection tasks. YOLO is trained on full images and directly optimizes detection performance, making it different from traditional object detection methods. It is also shown to be effective in detecting objects in artwork, where other methods struggle.
